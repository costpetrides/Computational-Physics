# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Interpolation/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 8.1

# %%
import matplotlib.pyplot as plt
import numpy as np

x= [-1.6, -1.0, -0.4, 0.2, 0.8, 1.4]
y= [0.278037, 0.606531, 0.923116, 0.980199, 0.726149, 0.375311]
n=len(x)

yp = 0  # By default
xp= 1   # interpolation point


# Implementing Lagrange Interpolation
for k in range(n):
    L = 1
    for i in range(n):
        if i != k:
            L = L * (xp - x[i])/(x[k] - x[i])
    yp = yp + L * y[k]


print('Interpolated value at %.5f is %.5f.' % (xp, yp))
# Out:
# Interpolated value at 1.00000 is 0.60037.

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([-1.6, -1.0, -0.4, 0.2, 0.8, 1.4])
y= np.array([0.278037, 0.606531, 0.923116, 0.980199, 0.726149, 0.375311])

xplt=np.linspace(x[0],x[-1])
yplt=np.array([],float)

for xp in xplt:
  yp=0

  for xi,yi in zip(x,y):
    yp+= yi * np.prod((xp- x[x != xi])/(xi- x[x != xi]))
  yplt=np.append(yplt,yp)

plt.plot(x,y,'ro',xplt,yplt,'b-')
plt.show()

# %% [markdown]
# # 8.2

# %%
x = [-1.6, -1.0, -0.4, 0.2, 0.8, 1.4]
y = [0.278037, 0.606531, 0.923116, 0.980199, 0.726149, 0.375311]
n=len(x)

def Q(xo):
  Q = np.zeros((n,n))

  for i in range(n):
    Q[i][0]=y[i]
    for j in range(1, i+1):
      Q[i][j] = ((xo - x[i-j]) * Q[i][j-1] - (xo - x[i]) * Q[i-1][j-1]) / (x[i] - x[i-j])
  return Q[i][i]

print('Interpolated value for f(0)= %.4f' %(Q(0)))
# Out:
# Interpolated value for f(0)= 0.9980

# %%
xplot = np.linspace(x[0],x[-1])
yplot = np.zeros(len(xplot))

i = 0
for k in xplot:
  yplot[i] += Q(k)
  i += 1

plt.plot(x,y,'ro',xplt,yplt,'b-')
plt.show()

# %% [markdown]
# # 8.3
