# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Neville%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download (14).jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

xdata = [-1.6, -1.0, -0.4, 0.2, 0.8, 1.4]
ydata = [0.278037, 0.606531, 0.923116, 0.980199, 0.726149, 0.375311]
n=len(xdata)

def Q(x):
 
  Q = np.zeros((n,n))
  
  for i in range(n):
    Q[i][0]=ydata[i]
    for j in range(1, i+1):
      Q[i][j] = ((x - xdata[i-j]) * Q[i][j-1] - (x - xdata[i]) * Q[i-1][j-1]) / (xdata[i] - xdata[i-j])

  return Q[i][i]

print('Interpolated value for f(0)=',Q(0))
# Out:
# Interpolated value for f(0)= 0.9979924567901234

# %%
xplot = np.linspace(xdata[0],xdata[-1])
yplot = np.zeros(len(x))

i = 0
for k in xplot:
  yplot[i] += Q(k)
  i += 1

plt.scatter(xdata,ydata)
plt.plot(xplot,yplot)
