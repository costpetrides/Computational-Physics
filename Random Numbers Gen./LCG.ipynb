# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/LCG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k

# %% [markdown]
# ![2CE9195B-5308-4403-B912-F9A1066BF665.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ** It can fall into a loop **

# %%
import numpy as np
import matplotlib.pyplot as plt
import time


def lcg(x,a,b,m,num_rand):
  gen=[]
  for i in range(num_rand):
    x=(a*x+b)%m
    gen.append(x)
  return np.array(gen)

time=time.perf_counter()
numbers=lcg(time,15,6,7,100)
print(numbers)


plt.plot(np.linspace(0,100,100), numbers)
# Out:
# [6.53440294 6.01604417 5.24066262 0.60993937 1.14909057 2.23635852
#  4.5453778  4.18066696 5.71000446 0.6500669  1.7510035  4.26505245
#  6.97578682 5.63680226 6.55203397 6.28050955 2.20764331 4.11464971
#  4.71974569 6.79618537 2.9427806  1.14170899 2.12563486 2.88452292
#  0.2678438  3.01765699 2.26485491 4.9728236  3.59235402 3.88531027
#  1.27965398 4.19480972 5.92214583 3.8321875  0.48281247 6.24218699
#  1.6328048  2.49207203 1.38108047 5.716207   0.74310496 3.14657435
#  4.19861532 5.97922975 4.68844631 6.32669461 2.90041908 0.50628616
#  6.59429234 6.91438507 4.71577603 6.7366405  2.04960751 1.74411268
#  4.1616902  5.42535298 3.38029477 0.70442152 2.56632281 2.4948422
#  1.42263302 6.33949532 3.09242984 3.38644764 0.79671466 3.95071997
#  2.26079948 4.9119922  2.67988307 4.19824598 5.97368964 4.60534467
#  5.08017007 5.20255103 0.03826548 6.57398223 6.6097335  0.14600246
#  1.19003687 2.85055298 6.75829465 2.37441973 6.61629589 0.24443839
# ...
