# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Lagrange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With list

# %% [markdown]
# ![download (13).jpg](data:image/jpeg;base64,...)

# %%
import matplotlib.pyplot as plt

x= [-1.6, -1.0, -0.4, 0.2, 0.8, 1.4]
y= [0.278037, 0.606531, 0.923116, 0.980199, 0.726149, 0.375311]
n=len(x)

yp = 0  # By default 
xp= 3   # interpolation point 


# Implementing Lagrange Interpolation
for k in range(n): 
    p = 1
    for i in range(n):
        if i != k:
            p = p * (xp - x[i])/(x[k] - x[i])
    yp = yp + p * y[k]    


print('Interpolated value at %.3f is %.3f.' % (xp, yp))

plt.scatter(x,y)
# Out:
# Interpolated value at 3.000 is 4.468.
