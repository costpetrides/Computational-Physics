# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Roots%20Finding/%20Bisection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2023-01-18 at 6.14.10 PM.png](data:image/png;base64,...)

# %% [markdown]
# **$y=x^3-x-1$ , [1,2]**

# %%
import matplotlib.pyplot as plt
import numpy as np
from  math import *

def f(x):
  return x**3-x-1

root=[]

a=1
b=2
for i in range(100):
  c=(a+b)/2
  if f(a)*f(c)<0:
    b=c
  else:
    a=c
  root+=[c]
  print('N=',i,'Sol=',c)
  if abs(f(c))<1.e-6:
   break
  
plt.plot(root)
plt.show()
# Out:
# N= 0 Sol= 1.5
# N= 1 Sol= 1.25
# N= 2 Sol= 1.375
# N= 3 Sol= 1.3125
# N= 4 Sol= 1.34375
# N= 5 Sol= 1.328125
# N= 6 Sol= 1.3203125
# N= 7 Sol= 1.32421875
# N= 8 Sol= 1.326171875
# N= 9 Sol= 1.3251953125
# N= 10 Sol= 1.32470703125
# N= 11 Sol= 1.324951171875
# N= 12 Sol= 1.3248291015625
# N= 13 Sol= 1.32476806640625
# N= 14 Sol= 1.324737548828125
# N= 15 Sol= 1.3247222900390625
# N= 16 Sol= 1.3247146606445312
# N= 17 Sol= 1.3247184753417969
# N= 18 Sol= 1.324716567993164
# N= 19 Sol= 1.3247175216674805
# N= 20 Sol= 1.3247179985046387
