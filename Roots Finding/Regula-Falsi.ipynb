# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Roots%20Finding/Regula-Falsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Regula-Falsi**
# ![regfalso.PNG](data:image/png;base64,...)

# %%
# y= x^3+2x^2-3x-1  , [1,2]
import numpy as np
import matplotlib.pyplot as plt
from math import *

def f(x):
  return x**3+2*x**2-3*x-1
a=1
b=2
for i in range(100):
  c = (f(b)*a-f(a)*b)/(f(b)-f(a))
  if (f(a))*f(y) <0 :
    b = c
  else:
   a = c
  if abs(f(c)) < 1.e-6:
    break
  print('N=',i, 'Sol:',c)

po=np.linspace(1,2,1000)
plt.plot(po,f(po))
plt.axhline(color='black')
# Out:
# N= 0 Sol: 1.1
# N= 1 Sol: 1.1517436380772856
# N= 2 Sol: 1.1768409099827861
# N= 3 Sol: 1.1886276732938286
# N= 4 Sol: 1.1940789112932393
# N= 5 Sol: 1.196582088205248
# N= 6 Sol: 1.197727754386817
# N= 7 Sol: 1.1982513177920089
# N= 8 Sol: 1.1984904184556142
# N= 9 Sol: 1.1985995764065946
# N= 10 Sol: 1.1986494037184505
# N= 11 Sol: 1.1986721468888464
# N= 12 Sol: 1.1986825274666322
# N= 13 Sol: 1.1986872653689649
# N= 14 Sol: 1.1986894278283893
# N= 15 Sol: 1.198690414808934
# N= 16 Sol: 1.1986908652818156
# N= 17 Sol: 1.1986910708843448
