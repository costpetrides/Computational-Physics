# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Siedel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download (12).jpg](data:image/jpeg;base64,...)

# %%
x1,x2,x3=1.,2.,3.

for i in range(10):
    x1 = (10 + x1)/3.
    x2 = (5 + x1 + x3)/3.
    x3 = (10 + 2*x2)/4
print('X1=',x1)
print('X2=',x2)
print('X3=',x3)
# Out:
# X1= 4.999932259648766
# X2= 4.999954817714948
# X3= 4.9999774088574735
