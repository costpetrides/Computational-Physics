# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/5-end%20point.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download (18).jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x*exp(x)

h=0.01
x=2

df = (-25*f(x) + 48*f(x+h) - 36*f(x+2*h) + 16*f(x+3*h) - 3*f(x+4*h))/(12*h)

print('df(%.2f)/dx = %.4f' %(x,df))
# Out:
# df(2.00)/dx = 22.1672
