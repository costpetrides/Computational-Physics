# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Solved%20Problems/Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Interpolation._page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Interpolation._page-0010.jpg](data:image/jpeg;base64,...)
