# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Solved%20Problems/Differentiation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Differentiation._page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Differentiation._page-0007.jpg](data:image/jpeg;base64,...)
