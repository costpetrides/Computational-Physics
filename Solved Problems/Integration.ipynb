# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Solved%20Problems/Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Integration._page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Integration._page-0005.jpg](data:image/jpeg;base64,...)
