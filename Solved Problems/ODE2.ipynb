# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/Solved%20Problems/ODE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DifferentialEquations._page-0007.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![DifferentialEquations._page-0013.jpg](data:image/jpeg;base64,...)
