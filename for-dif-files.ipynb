# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/for-dif-files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

v=[]

file=open("data.txt","r")
N=0

for x in file:
  v.append(float(x))
  N+=1

m=np.sum(v)/N
sd=np.sum((v-m)**2)/N

print(m)
print(sd)
# Out:
# 3.3870967741935485
# 2.075962539021852

# %%
v=[]

file=open("data1.txt","r")
N=0

for x in file:
  v.append(float(x))
  N+=1

m1=np.sum(v)/N
sd1=np.sum((v-m1)**2)/N

print(m1)
print(sd1)
# Out:
# 40.806451612903224
# 317.09157127991665

# %%
v=[]

file=open("data2.txt","r")
N=0

for x in file:
  v.append(float(x))
  N+=1

m2=np.sum(v)/N
sd2=np.sum((v-m2)**2)/N

print(m2)
print(sd2)
# Out:
# 254.83870967741936
# 24734.651404786673

# %%
mean=[m,m1,m2]
names=['Data','Data1','Data2']

fig = plt.figure(figsize=(5,3), dpi=900)
left, bottom, width, height = 0.1, 0.2, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height]) 
 
width = 0.5
ticks = np.arange(len(names))    
ax.bar(ticks, mean, width)


ax.set_ylabel('mean')
ax.set_title('μ for files')
ax.set_xticks(ticks + width/11)
ax.set_xticklabels(names)

ax.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
