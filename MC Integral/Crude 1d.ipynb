# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Computational-Physics/blob/main/MC%20Integral/Crude%201d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %%
 import numpy as np
import matplotlib.pyplot as plt

def f(x): return np.exp(x)       #function f(x)

def u(): return np.random.rand()   # function that genearte radnom numbers 

a,b=0,10                        # integral limits a and b values
N=10000
sumf=0    #   the sum of f(xi)
sumf2 =0   # sum of (f(x))^2

for i in range(N):
  x=10*u()             # x= random number ε [0,10]
  sumf+= f(x)          
  sumf2+=f(x)**2

meanf=sumf/N         #Mean of f(x)
sdf=sumf2/N-(meanf)**2      # SD of f(x)
sf = sdf**0.5
I=(b-a)*meanf
δΙ=(b-a)*(sf)/(N**0.5)


print('Integral =',I)
print('δΙ=',δΙ)
# Out:
# Integral = 22317.06152279123
# δΙ= 442.9348626409685
